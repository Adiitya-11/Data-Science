# %% [markdown]
# <a href="https://colab.research.google.com/github/Adiitya-11/Data-Science/blob/main/bar-chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

plt.ylabel("revenue(bln)")
plt.xlabel("Company")
plt.title("US Tech Stocks")

xpos = np.arange(len(company))
xpos
plt.xticks(xpos,company)
plt.bar(xpos-0.2 ,revenue, width = 0.4,label = "Revenue")
plt.legend()


profit=[40,2,34,12]
plt.bar(xpos+0.2,profit, width = 0.4, label = "Profit")
plt.legend()

# %%
plt.yticks(xpos,company)
plt.barh(xpos-0.2 ,revenue, height= 0.4,label = "Revenue")


profit=[40,2,34,12]
plt.barh(xpos+0.2,profit, height = 0.4,label = "Profit")
plt.legend()
